# %%
import tarfile

with tarfile.open("stock_model.tar.gz", "w:gz") as tar:
    tar.add("model/xgb_stock_model.joblib", arcname="xgb_stock_model.joblib")
    tar.add("stock_inference.py", arcname="stock_inference.py")

print("Created model.tar.gz")
# Out:
# Created model.tar.gz

# %%
import boto3

s3 = boto3.client("s3")

bucket = "bucket2-curated-stock"
s3.upload_file("stock_model.tar.gz", bucket, "models/stock_model.tar.gz")

# %%
pip install sagemaker==2.*
# Out:
# ...
#   Using cached sagemaker-2.257.0-py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached sagemaker_core-1.0.77-py3-none-any.whl.metadata (4.9 kB)
# ...
# Using cached sagemaker-2.257.0-py3-none-any.whl (1.7 MB)
# Using cached sagemaker_core-1.0.77-py3-none-any.whl (440 kB)
# ...
#   Attempting uninstall: sagemaker-core
#     Found existing installation: sagemaker-core 2.4.1
#     Uninstalling sagemaker-core-2.4.1:
#       Successfully uninstalled sagemaker-core-2.4.1
#   Attempting uninstall: sagemaker
#     Found existing installation: sagemaker 3.4.1
#     Uninstalling sagemaker-3.4.1:
#       Successfully uninstalled sagemaker-3.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sagemaker-train 1.4.1 requires sagemaker-core>=2.4.1, but you have sagemaker-core 1.0.77 which is incompatible.
# ...

# %%
pip uninstall sagemaker -y
# Out:
# Found existing installation: sagemaker 2.257.0
# Uninstalling sagemaker-2.257.0:
#   Successfully uninstalled sagemaker-2.257.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sagemaker --no-cache-dir
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 43.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sagemaker-core
#     Found existing installation: sagemaker-core 1.0.77
#     Uninstalling sagemaker-core-1.0.77:
#       Successfully uninstalled sagemaker-core-1.0.77
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sagemaker
print(sagemaker.__file__)
print(sagemaker.__version__)
# Out:
# /opt/conda/lib/python3.11/site-packages/sagemaker/__init__.py
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 import sagemaker
#       2 print(sagemaker.__file__)
# ----> 3 print(sagemaker.__version__)
#
# AttributeError: module 'sagemaker' has no attribute '__version__'

# %%
pip uninstall sagemaker -y
# Out:
# Found existing installation: sagemaker 3.4.1
# Uninstalling sagemaker-3.4.1:
#   Successfully uninstalled sagemaker-3.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall sagemaker -y
# Out:
# WARNING: Skipping sagemaker as it is not installed.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list | grep sagemaker
# Out:
# amazon_sagemaker_jupyter_ai_q_developer     1.2.9
# amazon_sagemaker_jupyter_scheduler          3.1.16
# amazon-sagemaker-sql-editor                 0.1.20
# amazon-sagemaker-sql-execution              0.1.9
# amazon-sagemaker-sql-magic                  0.1.4
# amzn_sagemaker_aiops_jupyterlab_extension   1.0.4
# sagemaker-core                              2.4.1
# sagemaker_gen_ai_jupyterlab_extension       1.0.13
# sagemaker-headless-execution-driver         0.0.13
# sagemaker-jupyterlab-emr-extension          0.4.3
# sagemaker-jupyterlab-extension              0.5.1
# sagemaker-jupyterlab-extension-common       0.2.16
# sagemaker-kernel-wrapper                    0.0.6
# sagemaker-mlflow                            0.1.1
# sagemaker-mlops                             1.4.1
# sagemaker-schema-inference-artifacts        0.0.5
# sagemaker-serve                             1.4.1
# sagemaker_studio                            1.1.5
# sagemaker-studio-analytics-extension        0.2.4
# ...

# %%
import sagemaker.serve
print(dir(sagemaker.serve))
# Out:
# ['__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__']
